# %% [markdown]
# # 4.1 Naive Bayes (Merge)

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Dataset used

# %%
merge_B_imb = pd.read_csv('merge_B_imb.csv')
merge_5L_imb = pd.read_csv('merge_5L_imb.csv')

merge_B_ROS = pd.read_csv('merge_B_ROS.csv')
merge_5L_ROS = pd.read_csv('merge_5L_ROS.csv')

merge_B_SMOTE = pd.read_csv('merge_B_SMOTE.csv')
merge_5L_SMOTE = pd.read_csv('merge_5L_SMOTE.csv')

print("merge_B_imb:", merge_B_imb.shape)
print("merge_5L_imb:", merge_5L_imb.shape)
print("merge_B_ROS:", merge_B_ROS.shape)
print("merge_5L_ROS:", merge_5L_ROS.shape)
print("merge_B_SMOTE:", merge_B_SMOTE.shape)
print("merge_5L_SMOTE:", merge_5L_SMOTE.shape)
# Out:
# merge_B_imb: (1287, 41)
# merge_5L_imb: (1287, 41)
# merge_B_ROS: (2540, 41)
# merge_5L_ROS: (3085, 41)
# merge_B_SMOTE: (2540, 41)
# merge_5L_SMOTE: (3085, 41)

# %%
rand_states = [7,69,101]

# %% [markdown]
# # Binary Classification

# %% [markdown]
# ## Student Background

# %% [markdown]
# ### SB before Data Balancing

# %%
tempB_SB_imb = []

y = merge_B_imb[['CGPA']]
X = merge_B_imb[['Age','Gender','Nationality', 'Living Status', 'Home Town', 'Faculty', 'Education Level',
                     'Years of Study', 'Completed Credit Hours']]

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')

        tempB_SB_imb.append([i,j,acc,pre,recall,f1])
        
dfB_SB_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SB_imb)
dfB_SB_imb
# Out:
# X: (1287, 9) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
dfB_SB_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.957364   0.975749  0.957364  0.966282
# 0.3        0.956934   0.976752  0.956934  0.966537
# 0.4        0.955987   0.973454  0.955987  0.964534
# 0.5        0.952381   0.972499  0.952381  0.962265

# %% [markdown]
# ### SB after RandomOverSampling

# %%
tempB_SB_ROS = []

y = merge_B_ROS[['CGPA']]
X = merge_B_ROS[['Age','Gender','Nationality', 'Living Status', 'Home Town', 'Faculty', 'Education Level',
                     'Years of Study', 'Completed Credit Hours']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
        
        tempB_SB_ROS.append([i,j,acc,pre,recall,f1])
        
dfB_SB_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SB_ROS)
dfB_SB_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SB_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.645669   0.666086  0.645669  0.636110
# 0.3        0.650919   0.668682  0.650919  0.641320
# 0.4        0.656496   0.672628  0.656496  0.648120
# 0.5        0.655381   0.670621  0.655381  0.646892

# %% [markdown]
# ### SB after SMOTE

# %%
tempB_SB_SMOTE = []

y = merge_B_SMOTE[['CGPA']]
X = merge_B_SMOTE[['Age','Gender','Nationality', 'Living Status', 'Home Town', 'Faculty', 'Education Level',
                     'Years of Study', 'Completed Credit Hours']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
        
        tempB_SB_SMOTE.append([i,j,acc,pre,recall,f1])
        
dfB_SB_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SB_SMOTE)
dfB_SB_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SB_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.770997   0.814612  0.770997  0.762893
# 0.3        0.771216   0.817700  0.771216  0.763078
# 0.4        0.778543   0.824699  0.778543  0.770774
# 0.5        0.778478   0.819909  0.778478  0.771576

# %% [markdown]
# ## Student History Grades

# %% [markdown]
# ### SHG before Data Balancing

# %%
tempB_SHG_imb = []

y = merge_B_imb[['CGPA']]
X = merge_B_imb[['Number of Subjects Failed','SPM Result (A)','SPM Result (B)','SPM Result (C)']]

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
        
        tempB_SHG_imb.append([i,j,acc,pre,recall,f1])
        
dfB_SHG_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SHG_imb)
dfB_SHG_imb
# Out:
# X: (1287, 4) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
dfB_SHG_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.970284   0.974149  0.970284  0.972183
# 0.3        0.976744   0.975902  0.976744  0.976307
# 0.4        0.970874   0.972805  0.970874  0.971806
# 0.5        0.969979   0.972020  0.969979  0.970988

# %% [markdown]
# ### SHG after RandomOverSampler

# %%
tempB_SHG_ROS = []

y = merge_B_ROS[['CGPA']]
X = merge_B_ROS[['Number of Subjects Failed','SPM Result (A)','SPM Result (B)','SPM Result (C)']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
        
        tempB_SHG_ROS.append([i,j,acc,pre,recall,f1])
        
dfB_SHG_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SHG_ROS)
dfB_SHG_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SHG_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.839239   0.840019  0.839239  0.839110
# 0.3        0.847332   0.848354  0.847332  0.847279
# 0.4        0.847441   0.848145  0.847441  0.847422
# 0.5        0.845407   0.846311  0.845407  0.845373

# %% [markdown]
# ### SHG after SMOTE

# %%
tempB_SHG_SMOTE = []

y = merge_B_SMOTE[['CGPA']]
X = merge_B_SMOTE[['Number of Subjects Failed','SPM Result (A)','SPM Result (B)','SPM Result (C)']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
        
        tempB_SHG_SMOTE.append([i,j,acc,pre,recall,f1])
        
dfB_SHG_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SHG_SMOTE)
dfB_SHG_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SHG_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.864173   0.864518  0.864173  0.864130
# 0.3        0.869641   0.869748  0.869641  0.869636
# 0.4        0.865157   0.865291  0.865157  0.865165
# 0.5        0.861942   0.861969  0.861942  0.861945

# %% [markdown]
# ## Student Opinion Towards MMU Environment

# %% [markdown]
# ### SOTME before Data Balancing

# %%
tempB_SOTME_imb = []

y = merge_B_imb[['CGPA']]
X = merge_B_imb[['Reason Study at Multimedia University', 'Lecture Class Capacity','Tutorial Class Capacity', 
                     'Classroom Facilities', 'Campus Environment']]

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_SOTME_imb.append([i,j,acc,pre,recall,f1])
        
dfB_SOTME_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SOTME_imb)
dfB_SOTME_imb
# Out:
# X: (1287, 5) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SOTME_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.987080   0.974340  0.987080  0.980666
# 0.3        0.987941   0.976030  0.987941  0.981949
# 0.4        0.986408   0.973003  0.986408  0.979659
# 0.5        0.986025   0.972245  0.986025  0.979086

# %% [markdown]
# ### SOTME after RandomOverSampler

# %%
tempB_SOTME_ROS = []

y = merge_B_ROS[['CGPA']]
X = merge_B_ROS[['Reason Study at Multimedia University', 'Lecture Class Capacity','Tutorial Class Capacity', 
                     'Classroom Facilities', 'Campus Environment']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_SOTME_ROS.append([i,j,acc,pre,recall,f1])
        
dfB_SOTME_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SOTME_ROS)
dfB_SOTME_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SOTME_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.702756   0.704877  0.702756  0.702375
# 0.3        0.693788   0.694742  0.693788  0.693655
# 0.4        0.685696   0.686748  0.685696  0.685468
# 0.5        0.672703   0.673487  0.672703  0.672579

# %% [markdown]
# ### SOTME after SMOTE

# %%
tempB_SOTME_SMOTE = []

y = merge_B_SMOTE[['CGPA']]
X = merge_B_SMOTE[['Reason Study at Multimedia University', 'Lecture Class Capacity','Tutorial Class Capacity', 
                     'Classroom Facilities', 'Campus Environment']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_SOTME_SMOTE.append([i,j,acc,pre,recall,f1])
        
dfB_SOTME_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SOTME_SMOTE)
dfB_SOTME_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SOTME_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.605643   0.611453  0.605643  0.603146
# 0.3        0.606299   0.610431  0.606299  0.604140
# 0.4        0.610236   0.614409  0.610236  0.607955
# 0.5        0.621260   0.624067  0.621260  0.620051

# %% [markdown]
# ## Student Family Background

# %% [markdown]
# ### SFB before Data Balancing

# %%
tempB_SFB_imb = []

y = merge_B_imb[['CGPA']]
X = merge_B_imb[['Family Size', "Parent's Education Level.Father", "Parent's Education Level.Mother", 
                     "Father's Occupation", "Mother's Occupation", 'Financial Difficulties', 'Financial Support']]

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_SFB_imb.append([i,j,acc,pre,recall,f1])
        
dfB_SFB_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SFB_imb)
dfB_SFB_imb
# Out:
# X: (1287, 7) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SFB_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.987080   0.974340  0.987080  0.980666
# 0.3        0.986219   0.976010  0.986219  0.981087
# 0.4        0.810356   0.970143  0.810356  0.861837
# 0.5        0.816253   0.972625  0.816253  0.864254

# %% [markdown]
# ### SFB after RandomOverSampler

# %%
tempB_SFB_ROS = []

y = merge_B_ROS[['CGPA']]
X = merge_B_ROS[['Family Size', "Parent's Education Level.Father", "Parent's Education Level.Mother", 
                     "Father's Occupation", "Mother's Occupation", 'Financial Difficulties', 'Financial Support']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_SFB_ROS.append([i,j,acc,pre,recall,f1])
        
dfB_SFB_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SFB_ROS)
dfB_SFB_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SFB_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.636483   0.637125  0.636483  0.636444
# 0.3        0.627734   0.628754  0.627734  0.626395
# 0.4        0.634186   0.636155  0.634186  0.632576
# 0.5        0.641470   0.643185  0.641470  0.640372

# %% [markdown]
# ### SFB after SMOTE

# %%
tempB_SFB_SMOTE = []

y = merge_B_SMOTE[['CGPA']]
X = merge_B_SMOTE[['Family Size', "Parent's Education Level.Father", "Parent's Education Level.Mother", 
                     "Father's Occupation", "Mother's Occupation", 'Financial Difficulties', 'Financial Support']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_SFB_SMOTE.append([i,j,acc,pre,recall,f1])
        
dfB_SFB_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SFB_SMOTE)
dfB_SFB_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SFB_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.726378   0.743780  0.726378  0.721387
# 0.3        0.727472   0.745666  0.727472  0.722836
# 0.4        0.728675   0.745508  0.728675  0.724163
# 0.5        0.731496   0.747551  0.731496  0.727408

# %% [markdown]
# ## Student Lifestyle

# %% [markdown]
# ### SL before Data Balancing

# %%
tempB_SL_imb = []

y = merge_B_imb[['CGPA']]
X = merge_B_imb[['Relationship Status', 'Scholarship', 'PTPTN', 'Skipping Class', 'Additional Course',
                    'Study Behavior', 'Study Time', 'Extra Curricular Activities', 'Part-time Job', 'Commute Time',
                    'Gaming', 'Alcohol Consumption', 'I have enough free time after class', 'Social Interaction',
                    'I hang out with friends']]

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_SL_imb.append([i,j,acc,pre,recall,f1])
        
dfB_SL_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SL_imb)
dfB_SL_imb
# Out:
# X: (1287, 15) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SL_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.821705   0.976934  0.821705  0.870903
# 0.3        0.584841   0.976057  0.584841  0.685012
# 0.4        0.478964   0.978980  0.478964  0.622808
# 0.5        0.448758   0.976912  0.448758  0.598969

# %% [markdown]
# ### SL after RandomOverSampler

# %%
tempB_SL_ROS = []

y = merge_B_ROS[['CGPA']]
X = merge_B_ROS[['Relationship Status', 'Scholarship', 'PTPTN', 'Skipping Class', 'Additional Course',
                    'Study Behavior', 'Study Time', 'Extra Curricular Activities', 'Part-time Job', 'Commute Time',
                    'Gaming', 'Alcohol Consumption', 'I have enough free time after class', 'Social Interaction',
                    'I hang out with friends']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_SL_ROS.append([i,j,acc,pre,recall,f1])
        
dfB_SL_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SL_ROS)
dfB_SL_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SL_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.790682   0.808935  0.790682  0.787475
# 0.3        0.783465   0.803288  0.783465  0.780297
# 0.4        0.800197   0.824639  0.800197  0.796628
# 0.5        0.791339   0.817685  0.791339  0.787314

# %% [markdown]
# ### SL after SMOTE

# %%
tempB_SL_SMOTE = []

y = merge_B_SMOTE[['CGPA']]
X = merge_B_SMOTE[['Relationship Status', 'Scholarship', 'PTPTN', 'Skipping Class', 'Additional Course',
                    'Study Behavior', 'Study Time', 'Extra Curricular Activities', 'Part-time Job', 'Commute Time',
                    'Gaming', 'Alcohol Consumption', 'I have enough free time after class', 'Social Interaction',
                    'I hang out with friends']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_SL_SMOTE.append([i,j,acc,pre,recall,f1])
        
dfB_SL_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SL_SMOTE)
dfB_SL_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SL_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.849081   0.869735  0.849081  0.846298
# 0.3        0.808399   0.857979  0.808399  0.801814
# 0.4        0.810696   0.859640  0.810696  0.804241
# 0.5        0.807349   0.857984  0.807349  0.800659

# %% [markdown]
# ## All Attributes

# %% [markdown]
# ### AA before Data Balancing

# %%
tempB_imb = []

y = merge_B_imb[['CGPA']]
X = merge_B_imb.drop(columns=["CGPA"])

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_imb.append([i,j,acc,pre,recall,f1])
        
dfB_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_imb)
dfB_imb
# Out:
# X: (1287, 40) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.934109   0.976607  0.934109  0.952960
# 0.3        0.814815   0.978614  0.814815  0.878309
# 0.4        0.789644   0.976347  0.789644  0.868178
# 0.5        0.762940   0.975746  0.762940  0.851328

# %% [markdown]
# ### AA after RandomOverSampler

# %%
tempB_ROS = []

y = merge_B_ROS[['CGPA']]
X = merge_B_ROS.drop(columns=["CGPA"])

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_ROS.append([i,j,acc,pre,recall,f1])
        
dfB_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_ROS)
dfB_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.912730   0.916529  0.912730  0.912658
# 0.3        0.901137   0.903093  0.901137  0.901080
# 0.4        0.900919   0.903314  0.900919  0.900827
# 0.5        0.896588   0.899084  0.896588  0.896488

# %% [markdown]
# ### AA after SMOTE

# %%
tempB_SMOTE = []

y = merge_B_SMOTE[['CGPA']]
X = merge_B_SMOTE.drop(columns=["CGPA"])

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        tempB_SMOTE.append([i,j,acc,pre,recall,f1])
        
dfB_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=tempB_SMOTE)
dfB_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfB_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.931102   0.937547  0.931102  0.930614
# 0.3        0.889764   0.906807  0.889764  0.888598
# 0.4        0.897310   0.912564  0.897310  0.896375
# 0.5        0.892126   0.909219  0.892126  0.891116

# %% [markdown]
# # 5 Level Classification

# %% [markdown]
# ## Student Background

# %% [markdown]
# ### SB before Data Balancing

# %%
temp5L_SB_imb = []

y = merge_5L_imb[['CGPA']]
X = merge_5L_imb[['Age','Gender','Nationality', 'Living Status', 'Home Town', 'Faculty', 'Education Level',
                     'Years of Study', 'Completed Credit Hours']]

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SB_imb.append([i,j,acc,pre,recall,f1])
        
df5L_SB_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SB_imb)
df5L_SB_imb
# Out:
# X: (1287, 9) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SB_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.456072   0.428007  0.456072  0.351801
# 0.3        0.453919   0.415097  0.453919  0.351869
# 0.4        0.450485   0.393692  0.450485  0.340884
# 0.5        0.453416   0.394821  0.453416  0.348423

# %% [markdown]
# ### SB after RandomOverSampler

# %%
temp5L_SB_ROS = []

y = merge_5L_ROS[['CGPA']]
X = merge_5L_ROS[['Age','Gender','Nationality', 'Living Status', 'Home Town', 'Faculty', 'Education Level',
                     'Years of Study', 'Completed Credit Hours']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SB_ROS.append([i,j,acc,pre,recall,f1])
        
df5L_SB_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SB_ROS)
df5L_SB_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SB_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.310643   0.334650  0.310643  0.282080
# 0.3        0.315335   0.318588  0.315335  0.285934
# 0.4        0.308482   0.333750  0.308482  0.281111
# 0.5        0.309138   0.348672  0.309138  0.280466

# %% [markdown]
# ### SB after SMOTE

# %%
temp5L_SB_SMOTE = []

y = merge_5L_SMOTE[['CGPA']]
X = merge_5L_SMOTE[['Age','Gender','Nationality', 'Living Status', 'Home Town', 'Faculty', 'Education Level',
                     'Years of Study', 'Completed Credit Hours']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SB_SMOTE.append([i,j,acc,pre,recall,f1])
        
df5L_SB_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SB_SMOTE)
df5L_SB_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SB_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.373852   0.351172  0.373852  0.318999
# 0.3        0.370770   0.350272  0.370770  0.314983
# 0.4        0.366288   0.341151  0.366288  0.310379
# 0.5        0.373731   0.344958  0.373731  0.323441

# %% [markdown]
# ## Student History Grades

# %% [markdown]
# ### SHG before Data Balancing

# %%
temp5L_SHG_imb = []

y = merge_5L_imb[['CGPA']]
X = merge_5L_imb[['Number of Subjects Failed','SPM Result (A)','SPM Result (B)','SPM Result (C)']]

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SHG_imb.append([i,j,acc,pre,recall,f1])
        
df5L_SHG_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SHG_imb)
df5L_SHG_imb
# Out:
# X: (1287, 4) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SHG_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.602067   0.574737  0.602067  0.553978
# 0.3        0.591731   0.571654  0.591731  0.537020
# 0.4        0.569579   0.529380  0.569579  0.510931
# 0.5        0.568323   0.522493  0.568323  0.508541

# %% [markdown]
# ### SHG after RandomOverSampler

# %%
temp5L_SHG_ROS = []

y = merge_5L_ROS[['CGPA']]
X = merge_5L_ROS[['Number of Subjects Failed','SPM Result (A)','SPM Result (B)','SPM Result (C)']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SHG_ROS.append([i,j,acc,pre,recall,f1])
        
df5L_SHG_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SHG_ROS)
df5L_SHG_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SHG_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.454349   0.419098  0.454349  0.409570
# 0.3        0.450684   0.420325  0.450684  0.408320
# 0.4        0.447596   0.413568  0.447596  0.404044
# 0.5        0.452366   0.420003  0.452366  0.408555

# %% [markdown]
# ### SHG after SMOTE

# %%
temp5L_SHG_SMOTE = []

y = merge_5L_SMOTE[['CGPA']]
X = merge_5L_SMOTE[['Number of Subjects Failed','SPM Result (A)','SPM Result (B)','SPM Result (C)']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SHG_SMOTE.append([i,j,acc,pre,recall,f1])
        
df5L_SHG_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SHG_SMOTE)
df5L_SHG_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SHG_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.452728   0.447048  0.452728  0.409200
# 0.3        0.455364   0.462796  0.455364  0.408954
# 0.4        0.452188   0.459963  0.452188  0.404450
# 0.5        0.447397   0.433369  0.447397  0.396773

# %% [markdown]
# ## Student Opinion Towards MMU Environment

# %% [markdown]
# ### SOTME before Data Balancing

# %%
temp5L_SOTME_imb = []

y = merge_5L_imb[['CGPA']]
X = merge_5L_imb[['Reason Study at Multimedia University', 'Lecture Class Capacity','Tutorial Class Capacity', 
                     'Classroom Facilities', 'Campus Environment']]

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SOTME_imb.append([i,j,acc,pre,recall,f1])
        
df5L_SOTME_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SOTME_imb)
df5L_SOTME_imb
# Out:
# X: (1287, 5) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SOTME_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.488372   0.239541  0.488372  0.321403
# 0.3        0.477175   0.258129  0.477175  0.316786
# 0.4        0.474434   0.283970  0.474434  0.310672
# 0.5        0.466356   0.311179  0.466356  0.326004

# %% [markdown]
# ### SOTME after RandomOverSampler

# %%
temp5L_SOTME_ROS = []

y = merge_5L_ROS[['CGPA']]
X = merge_5L_ROS[['Reason Study at Multimedia University', 'Lecture Class Capacity','Tutorial Class Capacity', 
                     'Classroom Facilities', 'Campus Environment']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SOTME_ROS.append([i,j,acc,pre,recall,f1])
        
df5L_SOTME_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SOTME_ROS)
df5L_SOTME_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SOTME_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.280929   0.280195  0.280929  0.246671
# 0.3        0.283657   0.274312  0.283657  0.247667
# 0.4        0.272285   0.275102  0.272285  0.246604
# 0.5        0.264420   0.284727  0.264420  0.227625

# %% [markdown]
# ### SOTME after SMOTE

# %%
temp5L_SOTME_SMOTE = []

y = merge_5L_SMOTE[['CGPA']]
X = merge_5L_SMOTE[['Reason Study at Multimedia University', 'Lecture Class Capacity','Tutorial Class Capacity', 
                     'Classroom Facilities', 'Campus Environment']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SOTME_SMOTE.append([i,j,acc,pre,recall,f1])
        
df5L_SOTME_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SOTME_SMOTE)
df5L_SOTME_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SOTME_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.330632   0.316468  0.330632  0.301816
# 0.3        0.325054   0.301365  0.325054  0.289675
# 0.4        0.323069   0.297165  0.323069  0.287113
# 0.5        0.327068   0.306822  0.327068  0.294870

# %% [markdown]
# ## Student Family Background

# %% [markdown]
# ### SFB before Data Balancing

# %%
temp5L_SFB_imb = []

y = merge_5L_imb[['CGPA']]
X = merge_5L_imb[['Family Size', "Parent's Education Level.Father", "Parent's Education Level.Mother", 
                     "Father's Occupation", "Mother's Occupation", 'Financial Difficulties', 'Financial Support']]

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SFB_imb.append([i,j,acc,pre,recall,f1])
        
df5L_SFB_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SFB_imb)
df5L_SFB_imb
# Out:
# X: (1287, 7) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SFB_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.478036   0.464061  0.478036  0.360970
# 0.3        0.462532   0.413324  0.462532  0.357135
# 0.4        0.368285   0.378048  0.368285  0.318448
# 0.5        0.359213   0.368995  0.359213  0.318377

# %% [markdown]
# ### SFB after RandomOverSampler

# %%
temp5L_SFB_ROS = []

y = merge_5L_ROS[['CGPA']]
X = merge_5L_ROS[['Family Size', "Parent's Education Level.Father", "Parent's Education Level.Mother", 
                     "Father's Occupation", "Mother's Occupation", 'Financial Difficulties', 'Financial Support']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SFB_ROS.append([i,j,acc,pre,recall,f1])
        
df5L_SFB_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SFB_ROS)
df5L_SFB_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SFB_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.245813   0.244732  0.245813  0.232254
# 0.3        0.255940   0.248311  0.255940  0.234572
# 0.4        0.253647   0.251270  0.253647  0.231338
# 0.5        0.259235   0.245582  0.259235  0.241771

# %% [markdown]
# ### SFB after SMOTE

# %%
temp5L_SFB_SMOTE = []

y = merge_5L_SMOTE[['CGPA']]
X = merge_5L_SMOTE[['Family Size', "Parent's Education Level.Father", "Parent's Education Level.Mother", 
                     "Father's Occupation", "Mother's Occupation", 'Financial Difficulties', 'Financial Support']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SFB_SMOTE.append([i,j,acc,pre,recall,f1])
        
df5L_SFB_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SFB_SMOTE)
df5L_SFB_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SFB_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.280929   0.239882  0.280929  0.225428
# 0.3        0.283297   0.244047  0.283297  0.225959
# 0.4        0.284981   0.243252  0.284981  0.223691
# 0.5        0.294880   0.263391  0.294880  0.237381

# %% [markdown]
# ## Student Lifestyle

# %% [markdown]
# ### SL before Data Balancing

# %%
temp5L_SL_imb = []

y = merge_5L_imb[['CGPA']]
X = merge_5L_imb[['Relationship Status', 'Scholarship', 'PTPTN', 'Skipping Class', 'Additional Course',
                    'Study Behavior', 'Study Time', 'Extra Curricular Activities', 'Part-time Job', 'Commute Time',
                    'Gaming', 'Alcohol Consumption', 'I have enough free time after class', 'Social Interaction',
                    'I hang out with friends']]

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SL_imb.append([i,j,acc,pre,recall,f1])
        
df5L_SL_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SL_imb)
df5L_SL_imb
# Out:
# X: (1287, 15) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SL_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.374677   0.393404  0.374677  0.358226
# 0.3        0.267873   0.392331  0.267873  0.285926
# 0.4        0.207120   0.349655  0.207120  0.250024
# 0.5        0.193064   0.341779  0.193064  0.237177

# %% [markdown]
# ### SL after RandomOverSampler

# %%
temp5L_SL_ROS = []

y = merge_5L_ROS[['CGPA']]
X = merge_5L_ROS[['Relationship Status', 'Scholarship', 'PTPTN', 'Skipping Class', 'Additional Course',
                    'Study Behavior', 'Study Time', 'Extra Curricular Activities', 'Part-time Job', 'Commute Time',
                    'Gaming', 'Alcohol Consumption', 'I have enough free time after class', 'Social Interaction',
                    'I hang out with friends']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SL_ROS.append([i,j,acc,pre,recall,f1])
        
df5L_SL_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SL_ROS)
df5L_SL_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SL_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.382496   0.373070  0.382496  0.323578
# 0.3        0.375810   0.363531  0.375810  0.315595
# 0.4        0.370340   0.356023  0.370340  0.319392
# 0.5        0.378700   0.353969  0.378700  0.325674

# %% [markdown]
# ### SL after SMOTE

# %%
temp5L_SL_SMOTE = []

y = merge_5L_SMOTE[['CGPA']]
X = merge_5L_SMOTE[['Relationship Status', 'Scholarship', 'PTPTN', 'Skipping Class', 'Additional Course',
                    'Study Behavior', 'Study Time', 'Extra Curricular Activities', 'Part-time Job', 'Commute Time',
                    'Gaming', 'Alcohol Consumption', 'I have enough free time after class', 'Social Interaction',
                    'I hang out with friends']]

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SL_SMOTE.append([i,j,acc,pre,recall,f1])
        
df5L_SL_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SL_SMOTE)
df5L_SL_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SL_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.354943   0.360159  0.354943  0.296188
# 0.3        0.347732   0.325952  0.347732  0.283041
# 0.4        0.343058   0.300595  0.343058  0.275637
# 0.5        0.322748   0.294096  0.322748  0.244884

# %% [markdown]
# ## All Attributes

# %% [markdown]
# ### AA before Data Balancing

# %%
temp5L_imb = []

y = merge_5L_imb[['CGPA']]
X = merge_5L_imb.drop(columns=['CGPA'])

print("X:", X.shape,"y:", y.shape)

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_imb.append([i,j,acc,pre,recall,f1])
        
df5L_imb = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_imb)
df5L_imb
# Out:
# X: (1287, 40) y: (1287, 1)
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_imb.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.524548   0.527896  0.524548  0.511260
# 0.3        0.453919   0.493023  0.453919  0.450321
# 0.4        0.438835   0.479098  0.438835  0.439817
# 0.5        0.418737   0.471233  0.418737  0.423648

# %% [markdown]
# ### AA after RandomOverSampler

# %%
temp5L_ROS = []

y = merge_5L_ROS[['CGPA']]
X = merge_5L_ROS.drop(columns=['CGPA'])

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_ROS.append([i,j,acc,pre,recall,f1])
        
df5L_ROS = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_ROS)
df5L_ROS
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_ROS.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.575905   0.557024  0.575905  0.549778
# 0.3        0.566595   0.549102  0.566595  0.540001
# 0.4        0.564830   0.544840  0.564830  0.537910
# 0.5        0.562108   0.541407  0.562108  0.535196

# %% [markdown]
# ### AA after SMOTE

# %%
temp5L_SMOTE = []

y = merge_5L_SMOTE[['CGPA']]
X = merge_5L_SMOTE.drop(columns=['CGPA'])

for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {}

        nb_model = GridSearchCV(GaussianNB(), param_grid, refit=True, cv=10, verbose=1)
        nb_model.fit(X_train, y_train)
        nb_pred = nb_model.predict(X_test)

        acc = accuracy_score(y_test,nb_pred)
        pre = precision_score(y_test, nb_pred, average='weighted')
        recall = recall_score(y_test, nb_pred, average='weighted')
        f1 = f1_score(y_test, nb_pred, average='weighted')
    
        temp5L_SMOTE.append([i,j,acc,pre,recall,f1])
        
df5L_SMOTE = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score'],data=temp5L_SMOTE)
df5L_SMOTE
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hazel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df5L_SMOTE.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.473258   0.467229  0.473258  0.439179
# 0.3        0.483441   0.480936  0.483441  0.443265
# 0.4        0.463803   0.457289  0.463803  0.419325
# 0.5        0.445669   0.449223  0.445669  0.396103
